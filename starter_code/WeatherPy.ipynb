# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
# !pip install citipy
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# print(city)
# Out:
# Number of cities in the list: 612

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = "https://api.openweathermap.org/data/2.5/weather?"

# Define an empty list to fetch the weather data for each city
city_data = []
units = "metric"
# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    # city_url = url + "appid=" + weather_api_key + "&q=" + city
    city_url = f"{url}&q={city}&appid={weather_api_key}&units={units}"
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        response = requests.get(city_url)
        city_weather = response.json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_humidity = city_weather['main']['humidity']
        city_clouds = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_country = city_weather['sys']['country']
        city_date = city_weather['dt']

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | edinburgh of the seven seas
# Processing Record 2 of Set 1 | thompson
# Processing Record 3 of Set 1 | adamstown
# Processing Record 4 of Set 1 | bredasdorp
# Processing Record 5 of Set 1 | albany
# Processing Record 6 of Set 1 | puerto ayora
# Processing Record 7 of Set 1 | anadyr
# Processing Record 8 of Set 1 | kapuskasing
# Processing Record 9 of Set 1 | dalandzadgad
# Processing Record 10 of Set 1 | bardai
# Processing Record 11 of Set 1 | bethel
# Processing Record 12 of Set 1 | ushuaia
# Processing Record 13 of Set 1 | san patricio
# Processing Record 14 of Set 1 | hihifo
# City not found. Skipping...
# Processing Record 15 of Set 1 | leh
# Processing Record 16 of Set 1 | invercargill
# Processing Record 17 of Set 1 | port-aux-francais
# Processing Record 18 of Set 1 | ilulissat
# Processing Record 19 of Set 1 | santa marta de ortigueira
# Processing Record 20 of Set 1 | iqaluit
# Processing Record 21 of Set 1 | tsaratanana
# Processing Record 22 of Set 1 | shadegan
# Processing Record 23 of Set 1 | waitangi
# Processing Record 24 of Set 1 | badger
# Processing Record 25 of Set 1 | hot springs national park
# City not found. Skipping...
# Processing Record 26 of Set 1 | west island
# Processing Record 27 of Set 1 | houlton
# Processing Record 28 of Set 1 | grytviken
# Processing Record 29 of Set 1 | udachny
# Processing Record 30 of Set 1 | orkney
# Processing Record 31 of Set 1 | atafu village
# Processing Record 32 of Set 1 | camden
# Processing Record 33 of Set 1 | shizunai-furukawacho
# Processing Record 34 of Set 1 | margaret river
# Processing Record 35 of Set 1 | saipan
# Processing Record 36 of Set 1 | margate
# Processing Record 37 of Set 1 | mangai
# Processing Record 38 of Set 1 | nemuro
# Processing Record 39 of Set 1 | polyarnyy
# Processing Record 40 of Set 1 | mapimi
# Processing Record 41 of Set 1 | lawas
# Processing Record 42 of Set 1 | teculutan
# Processing Record 43 of Set 1 | taulaga
# Processing Record 44 of Set 1 | palembang
# Processing Record 45 of Set 1 | aasiaat
# Processing Record 46 of Set 1 | cannonvale
# Processing Record 47 of Set 1 | montepuez
# Processing Record 48 of Set 1 | awjilah
# Processing Record 49 of Set 1 | yellowknife
# Processing Record 50 of Set 1 | racine
# Processing Record 0 of Set 2 | mana
# Processing Record 1 of Set 2 | tura
# Processing Record 2 of Set 2 | olds
# Processing Record 3 of Set 2 | weno
# Processing Record 4 of Set 2 | puerto baquerizo moreno
# Processing Record 5 of Set 2 | chonchi
# Processing Record 6 of Set 2 | utrik
# Processing Record 7 of Set 2 | bodo
# Processing Record 8 of Set 2 | minas de marcona
# Processing Record 9 of Set 2 | revda
# Processing Record 10 of Set 2 | ardestan
# Processing Record 11 of Set 2 | tranovaho
# City not found. Skipping...
# Processing Record 12 of Set 2 | olonkinbyen
# Processing Record 13 of Set 2 | puerto natales
# Processing Record 14 of Set 2 | whitehorse
# Processing Record 15 of Set 2 | lihue
# Processing Record 16 of Set 2 | avarua
# Processing Record 17 of Set 2 | vorkuta
# Processing Record 18 of Set 2 | taiohae
# City not found. Skipping...
# Processing Record 19 of Set 2 | juan griego
# Processing Record 20 of Set 2 | isafjordur
# Processing Record 21 of Set 2 | holualoa
# Processing Record 22 of Set 2 | alotau
# City not found. Skipping...
# Processing Record 23 of Set 2 | beloyarskiy
# Processing Record 24 of Set 2 | ta`u
# Processing Record 25 of Set 2 | shantobe
# Processing Record 26 of Set 2 | aral
# Processing Record 27 of Set 2 | severo-yeniseyskiy
# Processing Record 28 of Set 2 | georgetown
# Processing Record 29 of Set 2 | yeed
# Processing Record 30 of Set 2 | rio preto da eva
# Processing Record 31 of Set 2 | hermanus
# Processing Record 32 of Set 2 | rodez
# Processing Record 33 of Set 2 | i-n-salah
# Processing Record 34 of Set 2 | port mathurin
# Processing Record 35 of Set 2 | aripuana
# Processing Record 36 of Set 2 | constantia
# Processing Record 37 of Set 2 | upington
# Processing Record 38 of Set 2 | papatowai
# Processing Record 39 of Set 2 | hawaiian paradise park
# Processing Record 40 of Set 2 | yeppoon
# Processing Record 41 of Set 2 | yuzhno-kurilsk
# Processing Record 42 of Set 2 | nabire
# Processing Record 43 of Set 2 | nuuk
# Processing Record 44 of Set 2 | egersund
# Processing Record 45 of Set 2 | fada
# Processing Record 46 of Set 2 | jamestown
# Processing Record 47 of Set 2 | khovd
# Processing Record 48 of Set 2 | east london
# Processing Record 49 of Set 2 | fort frances
# Processing Record 0 of Set 3 | bilibino
# Processing Record 1 of Set 3 | upata
# Processing Record 2 of Set 3 | blackmans bay
# Processing Record 3 of Set 3 | sao gotardo
# Processing Record 4 of Set 3 | attapeu
# Processing Record 5 of Set 3 | souillac
# Processing Record 6 of Set 3 | luang prabang
# Processing Record 7 of Set 3 | mata-utu
# Processing Record 8 of Set 3 | kerikeri
# Processing Record 9 of Set 3 | ixtapa
# Processing Record 10 of Set 3 | nar'yan-mar
# Processing Record 11 of Set 3 | ancud
# Processing Record 12 of Set 3 | talnakh
# Processing Record 13 of Set 3 | punta arenas
# Processing Record 14 of Set 3 | palikir - national government center
# Processing Record 15 of Set 3 | keflavik
# Processing Record 16 of Set 3 | am djarass
# City not found. Skipping...
# Processing Record 17 of Set 3 | nikolayevsk-on-amure
# Processing Record 18 of Set 3 | cabo san lucas
# Processing Record 19 of Set 3 | lebu
# Processing Record 20 of Set 3 | benguela
# Processing Record 21 of Set 3 | mablethorpe
# City not found. Skipping...
# Processing Record 22 of Set 3 | fisterra
# Processing Record 23 of Set 3 | alto araguaia
# Processing Record 24 of Set 3 | mokopane
# Processing Record 25 of Set 3 | ad dabbah
# Processing Record 26 of Set 3 | papao
# Processing Record 27 of Set 3 | guachochi
# City not found. Skipping...
# Processing Record 28 of Set 3 | cofradia
# Processing Record 29 of Set 3 | syracuse
# Processing Record 30 of Set 3 | miranda
# Processing Record 31 of Set 3 | clodomira
# Processing Record 32 of Set 3 | port alfred
# Processing Record 33 of Set 3 | iho
# Processing Record 34 of Set 3 | dohar
# Processing Record 35 of Set 3 | alingsas
# Processing Record 36 of Set 3 | inarajan village
# Processing Record 37 of Set 3 | khandyga
# Processing Record 38 of Set 3 | laguna
# Processing Record 39 of Set 3 | mgandu
# Processing Record 40 of Set 3 | howard springs
# Processing Record 41 of Set 3 | luderitz
# Processing Record 42 of Set 3 | tiksi
# Processing Record 43 of Set 3 | palmer
# Processing Record 44 of Set 3 | portland
# Processing Record 45 of Set 3 | bungu
# Processing Record 46 of Set 3 | ola
# Processing Record 47 of Set 3 | stanley
# Processing Record 48 of Set 3 | slavgorod
# Processing Record 49 of Set 3 | okhotsk
# Processing Record 0 of Set 4 | mount gambier
# Processing Record 1 of Set 4 | stornoway
# Processing Record 2 of Set 4 | miyazaki
# Processing Record 3 of Set 4 | vilyuchinsk
# Processing Record 4 of Set 4 | baiti
# Processing Record 5 of Set 4 | bel ombre
# Processing Record 6 of Set 4 | crane
# Processing Record 7 of Set 4 | westport
# Processing Record 8 of Set 4 | la libertad
# Processing Record 9 of Set 4 | amursk
# Processing Record 10 of Set 4 | fort mcmurray
# Processing Record 11 of Set 4 | lompoc
# Processing Record 12 of Set 4 | zuni pueblo
# Processing Record 13 of Set 4 | as sulayyil
# Processing Record 14 of Set 4 | bunia
# Processing Record 15 of Set 4 | argostolion
# Processing Record 16 of Set 4 | camana
# Processing Record 17 of Set 4 | phan rang-thap cham
# Processing Record 18 of Set 4 | bartica
# Processing Record 19 of Set 4 | male
# Processing Record 20 of Set 4 | petawawa
# Processing Record 21 of Set 4 | uturoa
# Processing Record 22 of Set 4 | sao gabriel da cachoeira
# Processing Record 23 of Set 4 | vila velha
# Processing Record 24 of Set 4 | ribeira grande
# Processing Record 25 of Set 4 | alice springs
# Processing Record 26 of Set 4 | petropavlovsk-kamchatsky
# Processing Record 27 of Set 4 | santa cruz
# Processing Record 28 of Set 4 | chernyshevskiy
# Processing Record 29 of Set 4 | enewetak
# Processing Record 30 of Set 4 | san antonio de pale
# Processing Record 31 of Set 4 | novoagansk
# Processing Record 32 of Set 4 | aver-o-mar
# Processing Record 33 of Set 4 | port lincoln
# Processing Record 34 of Set 4 | boyolangu
# Processing Record 35 of Set 4 | qaqortoq
# Processing Record 36 of Set 4 | chernyshevsk
# Processing Record 37 of Set 4 | tazovsky
# Processing Record 38 of Set 4 | el hamma
# Processing Record 39 of Set 4 | salinas
# Processing Record 40 of Set 4 | longyearbyen
# Processing Record 41 of Set 4 | pacific grove
# Processing Record 42 of Set 4 | guichon
# Processing Record 43 of Set 4 | akureyri
# Processing Record 44 of Set 4 | valparaiso
# Processing Record 45 of Set 4 | heihe
# Processing Record 46 of Set 4 | mount pearl
# Processing Record 47 of Set 4 | vingt cinq
# City not found. Skipping...
# Processing Record 48 of Set 4 | campina verde
# Processing Record 49 of Set 4 | tefe
# Processing Record 0 of Set 5 | hithadhoo
# Processing Record 1 of Set 5 | fort st. john
# Processing Record 2 of Set 5 | nicoya
# Processing Record 3 of Set 5 | tanumah
# Processing Record 4 of Set 5 | batroun
# Processing Record 5 of Set 5 | yeppoon city centre
# City not found. Skipping...
# Processing Record 6 of Set 5 | kavieng
# Processing Record 7 of Set 5 | arraial do cabo
# Processing Record 8 of Set 5 | cidreira
# Processing Record 9 of Set 5 | lethem
# Processing Record 10 of Set 5 | nova sintra
# Processing Record 11 of Set 5 | paphos
# Processing Record 12 of Set 5 | san luis de la loma
# Processing Record 13 of Set 5 | mahanje
# Processing Record 14 of Set 5 | ad dujayl
# Processing Record 15 of Set 5 | happy valley-goose bay
# Processing Record 16 of Set 5 | colonia
# Processing Record 17 of Set 5 | sinan
# Processing Record 18 of Set 5 | mil'kovo
# Processing Record 19 of Set 5 | naze
# Processing Record 20 of Set 5 | arrifes
# Processing Record 21 of Set 5 | hasaki
# Processing Record 22 of Set 5 | mezhdurechensk
# Processing Record 23 of Set 5 | sretensk
# Processing Record 24 of Set 5 | perry
# Processing Record 25 of Set 5 | fale old settlement
# Processing Record 26 of Set 5 | sedalia
# Processing Record 27 of Set 5 | gaspar hernandez
# Processing Record 28 of Set 5 | alofi
# Processing Record 29 of Set 5 | jasper
# Processing Record 30 of Set 5 | namibe
# Processing Record 31 of Set 5 | lycksele
# Processing Record 32 of Set 5 | selebi-phikwe
# Processing Record 33 of Set 5 | gorom-gorom
# Processing Record 34 of Set 5 | recani
# Processing Record 35 of Set 5 | senanga
# Processing Record 36 of Set 5 | nadi
# Processing Record 37 of Set 5 | yurty
# Processing Record 38 of Set 5 | lent'ekhi
# Processing Record 39 of Set 5 | hilo
# Processing Record 40 of Set 5 | wailua homesteads
# Processing Record 41 of Set 5 | padang
# Processing Record 42 of Set 5 | robore
# Processing Record 43 of Set 5 | guerrero negro
# Processing Record 44 of Set 5 | manay
# Processing Record 45 of Set 5 | corpus christi
# Processing Record 46 of Set 5 | gadzhiyevo
# Processing Record 47 of Set 5 | maintirano
# Processing Record 48 of Set 5 | kulia village
# City not found. Skipping...
# Processing Record 49 of Set 5 | fort bragg
# Processing Record 0 of Set 6 | aykhal
# Processing Record 1 of Set 6 | alaghsas
# Processing Record 2 of Set 6 | haiku-pauwela
# Processing Record 3 of Set 6 | daru
# Processing Record 4 of Set 6 | la passe
# Processing Record 5 of Set 6 | morant bay
# Processing Record 6 of Set 6 | yel'nya
# Processing Record 7 of Set 6 | timaru
# Processing Record 8 of Set 6 | saudarkrokur
# Processing Record 9 of Set 6 | teguise
# Processing Record 10 of Set 6 | kununurra
# Processing Record 11 of Set 6 | grande prairie
# Processing Record 12 of Set 6 | tsiombe
# Processing Record 13 of Set 6 | ytyk-kyuyel'
# City not found. Skipping...
# Processing Record 14 of Set 6 | zhangjiakou
# Processing Record 15 of Set 6 | salinopolis
# Processing Record 16 of Set 6 | sao vicente
# Processing Record 17 of Set 6 | hamilton
# Processing Record 18 of Set 6 | steinbach
# Processing Record 19 of Set 6 | aroma
# Processing Record 20 of Set 6 | carnarvon
# Processing Record 21 of Set 6 | denbigh
# Processing Record 22 of Set 6 | juneau
# Processing Record 23 of Set 6 | zaysan
# Processing Record 24 of Set 6 | inderbor
# Processing Record 25 of Set 6 | kone
# Processing Record 26 of Set 6 | singkil
# Processing Record 27 of Set 6 | klyuchi
# Processing Record 28 of Set 6 | vorgashor
# Processing Record 29 of Set 6 | kodok
# City not found. Skipping...
# Processing Record 30 of Set 6 | pisco
# Processing Record 31 of Set 6 | phagwara
# Processing Record 32 of Set 6 | noumea
# Processing Record 33 of Set 6 | the dalles
# Processing Record 34 of Set 6 | praia da vitoria
# Processing Record 35 of Set 6 | castillos
# Processing Record 36 of Set 6 | ust-nera
# Processing Record 37 of Set 6 | boden
# Processing Record 38 of Set 6 | mbandaka
# Processing Record 39 of Set 6 | verkhnedneprovskiy
# Processing Record 40 of Set 6 | mufulira
# Processing Record 41 of Set 6 | smithers
# Processing Record 42 of Set 6 | prieska
# Processing Record 43 of Set 6 | 'ohonua
# City not found. Skipping...
# Processing Record 44 of Set 6 | kamaishi
# Processing Record 45 of Set 6 | st. john's
# Processing Record 46 of Set 6 | kimbe
# Processing Record 47 of Set 6 | afaahiti
# Processing Record 48 of Set 6 | brookings
# Processing Record 49 of Set 6 | bubaque
# Processing Record 0 of Set 7 | maridi
# Processing Record 1 of Set 7 | college
# Processing Record 2 of Set 7 | nova xavantina
# Processing Record 3 of Set 7 | flying fish cove
# Processing Record 4 of Set 7 | lospalos
# Processing Record 5 of Set 7 | puerto armuelles
# Processing Record 6 of Set 7 | tan-tan
# Processing Record 7 of Set 7 | new norfolk
# Processing Record 8 of Set 7 | roskilde
# Processing Record 9 of Set 7 | fortaleza
# Processing Record 10 of Set 7 | tecolots
# Processing Record 11 of Set 7 | sur
# Processing Record 12 of Set 7 | upi
# Processing Record 13 of Set 7 | shahpur
# Processing Record 14 of Set 7 | champoton
# Processing Record 15 of Set 7 | laramie
# Processing Record 16 of Set 7 | ganta
# Processing Record 17 of Set 7 | tobelo
# Processing Record 18 of Set 7 | taro
# Processing Record 19 of Set 7 | port blair
# Processing Record 20 of Set 7 | san jose de guanipa
# Processing Record 21 of Set 7 | tanrake village
# City not found. Skipping...
# Processing Record 22 of Set 7 | san lorenzo de esmeraldas
# Processing Record 23 of Set 7 | yei
# Processing Record 24 of Set 7 | charters towers
# Processing Record 25 of Set 7 | acarau
# Processing Record 26 of Set 7 | tolanaro
# Processing Record 27 of Set 7 | port saint john's
# Processing Record 28 of Set 7 | eyl
# Processing Record 29 of Set 7 | abadeh
# Processing Record 30 of Set 7 | hami
# Processing Record 31 of Set 7 | vernon
# Processing Record 32 of Set 7 | newport
# Processing Record 33 of Set 7 | markovo
# Processing Record 34 of Set 7 | aridaia
# Processing Record 35 of Set 7 | kalmeshwar
# Processing Record 36 of Set 7 | belmonte
# Processing Record 37 of Set 7 | general pico
# Processing Record 38 of Set 7 | kuqa
# Processing Record 39 of Set 7 | tarko-sale
# Processing Record 40 of Set 7 | lake havasu city
# Processing Record 41 of Set 7 | mili
# Processing Record 42 of Set 7 | jawf al maqbabah
# Processing Record 43 of Set 7 | miandrivazo
# Processing Record 44 of Set 7 | yarmouth
# Processing Record 45 of Set 7 | sandnessjoen
# Processing Record 46 of Set 7 | miarinarivo
# City not found. Skipping...
# Processing Record 47 of Set 7 | opuwo
# Processing Record 48 of Set 7 | al majaridah
# Processing Record 49 of Set 7 | changli
# Processing Record 0 of Set 8 | cadale
# Processing Record 1 of Set 8 | barcelos
# Processing Record 2 of Set 8 | marsh harbour
# Processing Record 3 of Set 8 | am timan
# Processing Record 4 of Set 8 | bamboo flat
# Processing Record 5 of Set 8 | bedesa
# Processing Record 6 of Set 8 | frontera
# Processing Record 7 of Set 8 | labrador city
# Processing Record 8 of Set 8 | vadso
# Processing Record 9 of Set 8 | gizo
# Processing Record 10 of Set 8 | codrington
# Processing Record 11 of Set 8 | port elizabeth
# Processing Record 12 of Set 8 | utena
# Processing Record 13 of Set 8 | sitka
# Processing Record 14 of Set 8 | vilyuysk
# Processing Record 15 of Set 8 | mahina
# Processing Record 16 of Set 8 | villiers
# Processing Record 17 of Set 8 | kavaratti
# Processing Record 18 of Set 8 | ponta delgada
# Processing Record 19 of Set 8 | levuka
# Processing Record 20 of Set 8 | kpandu
# Processing Record 21 of Set 8 | formosa
# Processing Record 22 of Set 8 | sorada
# Processing Record 23 of Set 8 | qal'at bishah
# City not found. Skipping...
# Processing Record 24 of Set 8 | corner brook
# Processing Record 25 of Set 8 | bela
# Processing Record 26 of Set 8 | puerto deseado
# Processing Record 27 of Set 8 | taltal
# Processing Record 28 of Set 8 | ulladulla
# Processing Record 29 of Set 8 | havre
# Processing Record 30 of Set 8 | morigaon
# Processing Record 31 of Set 8 | san pedro
# Processing Record 32 of Set 8 | akjoujt
# Processing Record 33 of Set 8 | rongelap
# Processing Record 34 of Set 8 | baud
# Processing Record 35 of Set 8 | golub-dobrzyn
# Processing Record 36 of Set 8 | geraldton
# Processing Record 37 of Set 8 | huanren
# Processing Record 38 of Set 8 | kalmunai
# Processing Record 39 of Set 8 | buka
# Processing Record 40 of Set 8 | arawa
# Processing Record 41 of Set 8 | sola
# Processing Record 42 of Set 8 | at taj
# Processing Record 43 of Set 8 | usta muhammad
# Processing Record 44 of Set 8 | berezovo
# Processing Record 45 of Set 8 | retreat
# Processing Record 46 of Set 8 | pacifica
# Processing Record 47 of Set 8 | kabinda
# Processing Record 48 of Set 8 | uthal
# Processing Record 49 of Set 8 | castelo do piaui
# Processing Record 0 of Set 9 | viedma
# Processing Record 1 of Set 9 | safford
# Processing Record 2 of Set 9 | prince george
# Processing Record 3 of Set 9 | acopiara
# Processing Record 4 of Set 9 | augusto correa
# Processing Record 5 of Set 9 | amherst
# Processing Record 6 of Set 9 | kodiak
# Processing Record 7 of Set 9 | matale
# Processing Record 8 of Set 9 | sisimiut
# Processing Record 9 of Set 9 | goshaingaon
# Processing Record 10 of Set 9 | chilecito
# Processing Record 11 of Set 9 | devinuwara
# City not found. Skipping...
# Processing Record 12 of Set 9 | sukhodol
# Processing Record 13 of Set 9 | northam
# Processing Record 14 of Set 9 | susuman
# Processing Record 15 of Set 9 | torrington
# Processing Record 16 of Set 9 | dar naim
# City not found. Skipping...
# Processing Record 17 of Set 9 | katsuura
# Processing Record 18 of Set 9 | puerto san carlos
# City not found. Skipping...
# Processing Record 19 of Set 9 | runaway bay
# Processing Record 20 of Set 9 | ljusdal
# Processing Record 21 of Set 9 | bonthe
# Processing Record 22 of Set 9 | kabalo
# Processing Record 23 of Set 9 | galesong
# Processing Record 24 of Set 9 | san jose del cabo
# Processing Record 25 of Set 9 | heunghae
# Processing Record 26 of Set 9 | nuevitas
# Processing Record 27 of Set 9 | baie-saint-paul
# Processing Record 28 of Set 9 | tame
# Processing Record 29 of Set 9 | kiunga
# Processing Record 30 of Set 9 | raja
# Processing Record 31 of Set 9 | quellon
# Processing Record 32 of Set 9 | scarborough
# Processing Record 33 of Set 9 | puerto santa
# Processing Record 34 of Set 9 | union
# Processing Record 35 of Set 9 | oranjemund
# Processing Record 36 of Set 9 | viligili
# City not found. Skipping...
# Processing Record 37 of Set 9 | yamada
# Processing Record 38 of Set 9 | pollau
# Processing Record 39 of Set 9 | nchelenge
# Processing Record 40 of Set 9 | rio gallegos
# Processing Record 41 of Set 9 | kingston
# Processing Record 42 of Set 9 | camalu
# Processing Record 43 of Set 9 | nelson
# Processing Record 44 of Set 9 | champerico
# Processing Record 45 of Set 9 | salym
# Processing Record 46 of Set 9 | zhangye
# Processing Record 47 of Set 9 | remire-montjoly
# Processing Record 48 of Set 9 | tadine
# Processing Record 49 of Set 9 | maharajganj
# Processing Record 0 of Set 10 | dunedin
# Processing Record 1 of Set 10 | wadowice
# Processing Record 2 of Set 10 | road town
# Processing Record 3 of Set 10 | yelizovo
# Processing Record 4 of Set 10 | toliara
# Processing Record 5 of Set 10 | bougouni
# Processing Record 6 of Set 10 | gobabis
# Processing Record 7 of Set 10 | wad medani
# Processing Record 8 of Set 10 | cobija
# Processing Record 9 of Set 10 | presidente dutra
# Processing Record 10 of Set 10 | sampit
# Processing Record 11 of Set 10 | illizi
# Processing Record 12 of Set 10 | baranchinskiy
# Processing Record 13 of Set 10 | klaksvik
# Processing Record 14 of Set 10 | pasni
# Processing Record 15 of Set 10 | paciran
# Processing Record 16 of Set 10 | hanzhong
# Processing Record 17 of Set 10 | baberu
# Processing Record 18 of Set 10 | jashpurnagar
# Processing Record 19 of Set 10 | sandi
# Processing Record 20 of Set 10 | santander
# Processing Record 21 of Set 10 | axim
# Processing Record 22 of Set 10 | zima
# Processing Record 23 of Set 10 | hays
# Processing Record 24 of Set 10 | hirara
# Processing Record 25 of Set 10 | aioun
# Processing Record 26 of Set 10 | elk city
# Processing Record 27 of Set 10 | duong dong
# Processing Record 28 of Set 10 | fuvahmulah
# City not found. Skipping...
# Processing Record 29 of Set 10 | whakatane
# Processing Record 30 of Set 10 | ingeniero guillermo n. juarez
# Processing Record 31 of Set 10 | magadan
# Processing Record 32 of Set 10 | guiuan
# Processing Record 33 of Set 10 | el nido
# Processing Record 34 of Set 10 | iskateley
# Processing Record 35 of Set 10 | wewak
# Processing Record 36 of Set 10 | faya-largeau
# Processing Record 37 of Set 10 | lamu
# Processing Record 38 of Set 10 | hadgaon
# Processing Record 39 of Set 10 | el aioun
# Processing Record 40 of Set 10 | belmopan
# Processing Record 41 of Set 10 | intendente alvear
# Processing Record 42 of Set 10 | atherton
# Processing Record 43 of Set 10 | al jawf
# Processing Record 44 of Set 10 | el calafate
# Processing Record 45 of Set 10 | callao
# Processing Record 46 of Set 10 | pudasjarvi
# Processing Record 47 of Set 10 | queenstown
# Processing Record 48 of Set 10 | necochea
# Processing Record 49 of Set 10 | dakhla
# Processing Record 0 of Set 11 | mejit
# Processing Record 1 of Set 11 | sofifi
# City not found. Skipping...
# Processing Record 2 of Set 11 | port alberni
# Processing Record 3 of Set 11 | amga
# Processing Record 4 of Set 11 | glendive
# Processing Record 5 of Set 11 | khash
# Processing Record 6 of Set 11 | backo petrovo selo
# Processing Record 7 of Set 11 | mukalla
# Processing Record 8 of Set 11 | berezovyy
# Processing Record 9 of Set 11 | mamuju
# Processing Record 10 of Set 11 | sabang
# Processing Record 11 of Set 11 | chibougamau
# Processing Record 12 of Set 11 | zadar
# Processing Record 13 of Set 11 | verkhniye kigi
# Processing Record 14 of Set 11 | carnot
# Processing Record 15 of Set 11 | kaga bandoro
# Processing Record 16 of Set 11 | kalat
# Processing Record 17 of Set 11 | mwingi
# Processing Record 18 of Set 11 | touros
# Processing Record 19 of Set 11 | vilhena
# Processing Record 20 of Set 11 | bandar lampung
# Processing Record 21 of Set 11 | ubinskoye
# Processing Record 22 of Set 11 | drobeta-turnu severin
# Processing Record 23 of Set 11 | banbridge
# Processing Record 24 of Set 11 | nova vicosa
# Processing Record 25 of Set 11 | akobo
# Processing Record 26 of Set 11 | newman
# Processing Record 27 of Set 11 | islamkot
# Processing Record 28 of Set 11 | burao
# Processing Record 29 of Set 11 | korla
# Processing Record 30 of Set 11 | ndola
# Processing Record 31 of Set 11 | bandarbeyla
# Processing Record 32 of Set 11 | manicore
# Processing Record 33 of Set 11 | mount isa
# Processing Record 34 of Set 11 | fish town
# Processing Record 35 of Set 11 | emerald
# Processing Record 36 of Set 11 | montecarlo
# Processing Record 37 of Set 11 | saldanha
# Processing Record 38 of Set 11 | saint-joseph
# Processing Record 39 of Set 11 | beau vallon
# Processing Record 40 of Set 11 | saint croix
# Processing Record 41 of Set 11 | karratha
# Processing Record 42 of Set 11 | labytnangi
# Processing Record 43 of Set 11 | hamlin
# Processing Record 44 of Set 11 | goba
# Processing Record 45 of Set 11 | aitape
# Processing Record 46 of Set 11 | sarina
# Processing Record 47 of Set 11 | petrovsk
# Processing Record 48 of Set 11 | san andres
# Processing Record 49 of Set 11 | eforie sud
# Processing Record 0 of Set 12 | mersing
# Processing Record 1 of Set 12 | glace bay
# Processing Record 2 of Set 12 | kruisfontein
# Processing Record 3 of Set 12 | port glaud
# City not found. Skipping...
# Processing Record 4 of Set 12 | deqen
# Processing Record 5 of Set 12 | sishui
# Processing Record 6 of Set 12 | zheshart
# Processing Record 7 of Set 12 | dudinka
# Processing Record 8 of Set 12 | novodvinsk
# Processing Record 9 of Set 12 | hotan
# Processing Record 10 of Set 12 | kapa'a
# Processing Record 11 of Set 12 | la peca
# Processing Record 12 of Set 12 | warmbad
# Processing Record 13 of Set 12 | kashgar
# Processing Record 14 of Set 12 | bargara
# City not found. Skipping...
# Processing Record 15 of Set 12 | tinajo
# Processing Record 16 of Set 12 | mishkino
# Processing Record 17 of Set 12 | tamanrasset
# Processing Record 18 of Set 12 | khenifra
# Processing Record 19 of Set 12 | tual
# Processing Record 20 of Set 12 | tianpeng
# Processing Record 21 of Set 12 | tumbotino
# Processing Record 22 of Set 12 | bereeda
# Processing Record 23 of Set 12 | rio grande
# Processing Record 24 of Set 12 | felidhoo
# City not found. Skipping...
# Processing Record 25 of Set 12 | hammerfest
# Processing Record 26 of Set 12 | matadi
# Processing Record 27 of Set 12 | colon
# Processing Record 28 of Set 12 | sitia
# Processing Record 29 of Set 12 | bayanhongor
# Processing Record 30 of Set 12 | egilsstadir
# Processing Record 31 of Set 12 | santanyi
# Processing Record 32 of Set 12 | ivdel'
# Processing Record 33 of Set 12 | bantogon
# Processing Record 34 of Set 12 | homer
# Processing Record 35 of Set 12 | tralee
# Processing Record 36 of Set 12 | kiffa
# Processing Record 37 of Set 12 | namie
# Processing Record 38 of Set 12 | mandalgovi
# Processing Record 39 of Set 12 | cill airne
# Processing Record 40 of Set 12 | lodwar
# Processing Record 41 of Set 12 | comilla
# Processing Record 42 of Set 12 | alesund
# Processing Record 43 of Set 12 | pathein
# Processing Record 44 of Set 12 | paramirim
# Processing Record 45 of Set 12 | cruzeiro do oeste
# Processing Record 46 of Set 12 | dokkum
# Processing Record 47 of Set 12 | huangyan
# Processing Record 48 of Set 12 | umba
# Processing Record 49 of Set 12 | murun-kuren
# Processing Record 0 of Set 13 | bandon
# Processing Record 1 of Set 13 | uige
# Processing Record 2 of Set 13 | newcastle
# Processing Record 3 of Set 13 | sri dungargarh
# Processing Record 4 of Set 13 | terrace
# Processing Record 5 of Set 13 | kargasok
# Processing Record 6 of Set 13 | ambalangoda
# Processing Record 7 of Set 13 | lashio
# Processing Record 8 of Set 13 | broome
# Processing Record 9 of Set 13 | george town
# Processing Record 10 of Set 13 | ingeniero jacobacci
# Processing Record 11 of Set 13 | beyneu
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          586
# Lat           586
# Lng           586
# Max Temp      586
# Humidity      586
# Cloudiness    586
# Wind Speed    586
# Country       586
# Date          586
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#                           City      Lat       Lng  Max Temp  Humidity  \
# 0  edinburgh of the seven seas -37.0676  -12.3116     15.14        85
# 1                     thompson  55.7435  -97.8558      7.09        93
# 2                    adamstown -25.0660 -130.1015     18.69        64
# 3                   bredasdorp -34.5322   20.0403     13.48        49
# 4                       albany  42.6001  -73.9662     19.77        94
#
#    Cloudiness  Wind Speed Country        Date
# 0         100       15.40      SH  1693047401
# 1           0        1.54      CA  1693047226
# 2          82        6.82      PN  1693047167
# 3          66        6.63      ZA  1693047414
# 4          49        2.07      US  1693047211

# %%
# Export the City_Data into a csv
city_data_df.to_csv("output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                 City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0               faya  18.3851   42.4509     22.06        35          21
# 1            farsund  58.0948    6.8047     13.30       100           0
# 2        new norfolk -42.7826  147.0587     11.72        58          12
# 3          jamestown  42.0970  -79.2353      5.77        77         100
# 4            lanzhou  36.0564  103.7922     14.53        48          59
#
#          Wind Speed Country        Date
# City_ID
# 0              2.60      SA  1666108228
# 1              7.65      NO  1666108228
# 2              1.34      AU  1666108230
# 3              9.77      US  1666107934
# 4              1.20      CN  1666108230

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
# YOUR CODE HERE
plt.scatter(city_data_df['Lat'], city_data_df['Max Temp'], marker='o', color='darkCyan', edgecolor='black', alpha=0.8)


# Incorporate the other graph properties
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (C)')
plt.title('City Max Latitude vs. Temperature(2022-10-18)')
plt.grid(True)

# Save the figure--
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
plt.scatter(city_data_df['Lat'], city_data_df['Humidity'], marker='o', color='darkCyan', edgecolor='black', alpha=0.8)

# Incorporate the other graph properties
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.title('City Max Latitude vs. Humidity(2022-10-18)')
plt.grid(True)


# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
plt.scatter(city_data_df['Lat'], city_data_df['Cloudiness'], marker='o', color='darkCyan', edgecolor='black', alpha=0.8)

# Incorporate the other graph properties
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.title('City Latitude vs. Cloudiness(2022-10-18)')
plt.grid(True)


# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
plt.scatter(city_data_df['Lat'], city_data_df['Wind Speed'], marker='o', color='darkCyan', edgecolor='black', alpha=0.8)

# Incorporate the other graph properties
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (m/s)')
plt.title('City Latitude vs. Wind Speed (2022-10-18)')
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df=city_data_df[city_data_df['Lat'] >= 0]

# Display sample data
northern_hemi_df.head()
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 1      thompson  55.7435  -97.8558      7.09        93           0
# 4        albany  42.6001  -73.9662     19.77        94          49
# 6        anadyr  64.7500  177.4833      2.28        93          20
# 7   kapuskasing  49.4169  -82.4331      7.05        87         100
# 8  dalandzadgad  43.5708  104.4250     24.78        19         100
#
#    Wind Speed Country        Date
# 1        1.54      CA  1693047226
# 4        2.07      US  1693047211
# 6        3.00      RU  1693047223
# 7        1.54      CA  1693047447
# 8        1.96      MN  1693047496

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df=city_data_df[city_data_df['Lat'] < 0]

# Display sample data
southern_hemi_df.head()
# Out:
#                            City      Lat       Lng  Max Temp  Humidity  \
# 0   edinburgh of the seven seas -37.0676  -12.3116     15.14        85
# 2                     adamstown -25.0660 -130.1015     18.69        64
# 3                    bredasdorp -34.5322   20.0403     13.48        49
# 5                  puerto ayora  -0.7393  -90.3518     23.64        96
# 11                      ushuaia -54.8000  -68.3000      1.81        87
#
#     Cloudiness  Wind Speed Country        Date
# 0          100       15.40      SH  1693047401
# 2           82        6.82      PN  1693047167
# 3           66        6.63      ZA  1693047414
# 5           26        2.24      EC  1693047171
# 11          20        3.60      AR  1693047176

# %%
# Out:
#                  City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 2         new norfolk -42.7826  147.0587     11.72        58          12
# 5             ushuaia -54.8000  -68.3000      8.81        81          75
# 7           carnarvon -24.8667  113.6333     20.02        76           0
# 9        saint-pierre -21.3393   55.4781     22.82        68           0
# 10           colorado -22.8375  -51.9731     20.36        86          96
#
#          Wind Speed Country        Date
# City_ID
# 2              1.34      AU  1666108230
# 5              3.09      AR  1666108231
# 7              7.46      AU  1666108232
# 9              5.14      RE  1666108236
# 10             4.69      BR  1666107965

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
# Linear regression on Northern Hemisphere
plt.scatter(northern_hemi_df['Lat'], northern_hemi_df['Max Temp'], marker='o', color='navy', alpha=0.8)
x_values = northern_hemi_df['Lat']
y_values =  northern_hemi_df['Max Temp']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.plot(x_values,regress_values,"r-")
# Incorporate the other graph properties
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (C)')
# plt.title('Northern Hemisphere City Latitude vs. Max Temperature')
print(f"The r-value is {round(rvalue,2)}")

# Show plot
plt.annotate(line_eq, (10, 10), fontsize=12, color='red')
plt.show()
# Out:
# The r-value is -0.68

# %%
# Linear regression on Southern Hemisphere
plt.scatter(southern_hemi_df['Lat'], southern_hemi_df['Max Temp'], marker='o', color='navy', alpha=0.8)
x_values = southern_hemi_df['Lat']
y_values =  southern_hemi_df['Max Temp']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.plot(x_values,regress_values,"r-")
# Incorporate the other graph properties
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (C)')
# plt.title('Northern Hemisphere City Latitude vs. Max Temperature')
print(f"The r-value is {round(rvalue,2)}")

# Show plot
plt.annotate(line_eq, (-50, 30), fontsize=12, color='red')
plt.show()
# Out:
# The r-value is 0.84

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %%
#1-Temperature vs. Latitude

# 1-1) The relation between Northern Hemisphere city max Temperature (C) vs. Latitude is: y = -0.29x + 33.96 (rvalue = -0.68)
# The negative correlation in the Northern Hemisphere means that you will likely encounter cooler temperatures as you move farther away from the equator (higher latitudes).

# 1-2) The relation between Southern Hemisphere city max Temperature (C) vs. Latitude is: y = 0.56x + 31.26 (rvalue = 0.84)
# The positive correlation in the Southern Hemisphere indicates that temperatures tend to become warmer as you move closer to the equator (lower latitudes)


# An r value of -0.68 and 0.84 indicates moderate and strong correlations, respectively. A value closer to -1 or 1 indicates a stronger linear relationship. 
# However, the models are also based on random city data analysis and may not predict exact temperature values in every scenario. They offer a simplified 
# representation of the general trend between latitude and temperature.

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
# Linear regression on Northern Hemisphere
plt.scatter(northern_hemi_df['Lat'], northern_hemi_df['Humidity'], marker='o', color='navy', alpha=0.8)
x_values = northern_hemi_df['Lat']
y_values =  northern_hemi_df['Humidity']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.plot(x_values,regress_values,"r-")
# Incorporate the other graph properties
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
# plt.title('Northern Hemisphere City Latitude vs. Max Temperature')
print(f"The r-value is {round(rvalue,2)}")

# Show plot
plt.annotate(line_eq, (50, 10), fontsize=12, color='red')
plt.show()
# Out:
# The r-value is 0.08

# %%
# Southern Hemisphere
plt.scatter(southern_hemi_df['Lat'], southern_hemi_df['Humidity'], marker='o', color='navy', alpha=0.8)
x_values = southern_hemi_df['Lat']
y_values =  southern_hemi_df['Humidity']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.plot(x_values,regress_values,"r-")
# Incorporate the other graph properties
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
# plt.title('Northern Hemisphere City Latitude vs. Max Temperature')
print(f"The r-value is {round(rvalue,2)}")

# Show plot
plt.annotate(line_eq, (-50, 20), fontsize=12, color='red')
plt.show()
# Out:
# The r-value is -0.04

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %%
#2-Humidity vs. Latitude

# 2-1) The relation between Northern Hemisphere city Humidity (%) vs. Latitude is: y = 0.11x + 65 (rvalue = 0.08)

# 2-2) The relation between Southern Hemisphere city Humidity (%) vs. Latitude is: y = -0.07x + 62.97 (rvalue = -0.04)

# Both in the Northern and Southern Hemispheres, the relationship between humidity and latitude appears very weak based on the low r-values.
# While you've observed some relationships between humidity and latitude, the low R-values and small slopes suggest 
# that latitude might not be a significant predictor of humidity on its own.
# Other variables are likely at play, and further analysis or consideration of additional factors could provide more insights.
# This means that latitude alone is not a strong predictor of humidity.
# The slopes of the regression lines are very close to zero, 
# which reinforces the idea that the changes in humidity are relatively minor as latitude changes

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
# Linear regression on Northern Hemisphere
plt.scatter(northern_hemi_df['Lat'], northern_hemi_df['Cloudiness'], marker='o', color='navy', alpha=0.8)
x_values = northern_hemi_df['Lat']
y_values =  northern_hemi_df['Cloudiness']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.plot(x_values,regress_values,"r-")
# Incorporate the other graph properties
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
# plt.title('Northern Hemisphere City Latitude vs. Max Temperature')
print(f"The r-value is {round(rvalue,2)}")

# Show plot
plt.annotate(line_eq, (50, 10), fontsize=12, color='red')
plt.show()
# Out:
# The r-value is 0.11

# %%
# Southern Hemisphere
# Linear regression on Northern Hemisphere
plt.scatter(southern_hemi_df['Lat'], southern_hemi_df['Cloudiness'], marker='o', color='navy', alpha=0.8)
x_values = southern_hemi_df['Lat']
y_values =  southern_hemi_df['Cloudiness']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.plot(x_values,regress_values,"r-")
# Incorporate the other graph properties
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
# plt.title('Northern Hemisphere City Latitude vs. Max Temperature')
print(f"The r-value is {round(rvalue,2)}")

# Show plot
plt.annotate(line_eq, (-50, 20), fontsize=12, color='red')
plt.show()
# Out:
# The r-value is 0.01

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %%
#3-Cloudiness vs. Latitude

# 3-1) The relation between Northern Hemisphere city Cloudiness (%) vs. Latitude is: y = 0.21x + 51.63 (rvalue = 0.11)

# 3-2) The relation between Southern Hemisphere city Cloudiness (%) vs. Latitude is: y = 0.04x + 48.24 (rvalue = 0.01)
# The relationship between cloudiness and latitude appears weak in the Northern and Southern Hemispheres, as indicated by the low R-values.
# The positive slopes of the regression lines suggest that there's a tendency for cloudiness to increase with increasing latitude, but the magnitude of the effect is small.
# Various complex atmospheric and meteorological factors influence cloudiness, including local weather patterns, wind patterns, and geographical features. These factors might contribute to the weak relationships observed here.
# In summary, the weak relationships between cloudiness and latitude in both hemispheres and the low R-values indicate that latitude alone might not be a strong predictor of cloudiness. Other factors likely play a significant role 
# in determining cloudiness levels in a given location. Further investigation and consideration of additional variables could provide more insights.

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
plt.scatter(northern_hemi_df['Lat'], northern_hemi_df['Wind Speed'], marker='o', color='navy', alpha=0.8)
x_values = northern_hemi_df['Lat']
y_values =  northern_hemi_df['Wind Speed']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.plot(x_values,regress_values,"r-")
# Incorporate the other graph properties
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (m/s)')
# plt.title('Northern Hemisphere City Latitude vs. Max Temperature')
print(f"The r-value is {round(rvalue,2)}")

# Show plot
plt.annotate(line_eq, (10, 13), fontsize=12, color='red')
plt.show()
# Out:
# The r-value is -0.06

# %%
# Southern Hemisphere
# Linear regression on Northern Hemisphere
plt.scatter(southern_hemi_df['Lat'], southern_hemi_df['Wind Speed'], marker='o', color='navy', alpha=0.8)
x_values = southern_hemi_df['Lat']
y_values =  southern_hemi_df['Wind Speed']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.plot(x_values,regress_values,"r-")
# Incorporate the other graph properties
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (m/s)')
# plt.title('Northern Hemisphere City Latitude vs. Max Temperature')
print(f"The r-value is {round(rvalue,2)}")

# Show plot
plt.annotate(line_eq, (-50, 13), fontsize=12, color='red')
plt.show()
# Out:
# The r-value is -0.15

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %%
#4-Wind Speed(m/s) vs. Latitude

# 4-1) The relation between Northern Hemisphere city Cloudiness (%) vs. Latitude is: y = -0.01x + 3.87 (rvalue = -0.06)

# 4-2) The relation between Southern Hemisphere city Cloudiness (%) vs. Latitude is: y = -0.03x + 3.58 (rvalue = -0.15)
# The relationships between wind speed and latitude in both hemispheres are weak, as indicated by the low r-values.
# The negative slopes in both cases suggest that wind speed decreases as you move away from the equator, regardless of hemisphere.
# While latitude does play a role in wind speed patterns, it is not the sole determinant. Local topography, weather systems, ocean currents, and 
# atmospheric conditions all contribute to the variability in wind speed.
# In summary, while there is a negative trend between wind speed and latitude, the weak correlations suggest that latitude is not a strong 
# predictor of wind speed. Many complex factors influence wind speed, and further investigation into local meteorological conditions 
# is necessary to fully understand wind speed patterns.
